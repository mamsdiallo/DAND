# %%
# Required Libraries
# environment todelete
import numpy as np
import pandas as pd
import html5lib
import matplotlib.pyplot as plt
import seaborn as sns

# Settings
sns.set_style('whitegrid')
# %matplotlib inline

# Get the Data
#pf_crew = pd.read_html('https://www.encyclopedia-titanica.org/titanic-crew-list/') 
#pf_crew2 = pd.read_html('https://www.encyclopedia-titanica.org/titanic-crew-list/')[0]

from bs4 import BeautifulSoup
import urllib3

http = urllib3.PoolManager()

url = 'https://www.encyclopedia-titanica.org/titanic-crew-list/'
response = http.request('GET', url)
#soup = BeautifulSoup(response.data)
soup = BeautifulSoup(response.data, "lxml")
# Out:
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
# print content
#print soup

# %%
columns = ['Name','Age','LastName']
newDF = pd.DataFrame(columns=columns) #creates a new dataframe that's empty

# %%
# scrape Nome, Cognome, Email.
# actual table: Name	Age	Class/Dept	Ticket	Joined	Job	Boat [Body]	
count = 0
for tr in soup.find_all('tr')[2:]:
    tds = tr.find_all('td')
    dic = {}
    #print "Name: %s, Age: %s, Ticket: %s, Joined: %s" % \
    #      (tds[0].text, tds[1].text, tds[3].text,tds[4])
    #newDF.append({'Name':tds[0].text,'Age':tds[1].text}, ignore_index = True) 
    # force age into numeric
    dico = {'Name':tds[0].text.strip(),'Age':pd.to_numeric(tds[1].text,errors='coerce')}
    #newDF.append(dico, ignore_index = True)
    #newDF.iloc[count, 0] = 
    #print dico['Name']
    
    pattern = ' '
    string = dico['Name']
    m = re.split(pattern, string)
    n = len(m[0])+len(m[1])+2
    newDF.loc[count,'Name'] = m[0].capitalize()+' '+m[1]+'.'+' '+string[n:]    
    
    string = newDF.loc[count,'Name']
    m = re.search('^[a-zA-Z\']+', string)
    txt = m.group(0)
    t = txt.capitalize()
    newDF.loc[count,'LastName'] = t  
    #newDF.loc[count,'Name'] = dico['Name']
    #newDF.iloc[count,1] = 
    #print dico['Age']
    newDF.loc[count,'Age'] = dico['Age'] 
    #pd.to_numeric(df.Age, errors='coerce')
    #print dico
    # print newDF[count] 
    count +=1

# %%
# All doctors are male
newDF[newDF.Name.str.contains(u'Dr')]
# Out:
#                                        Name Age    LastName
# 415           Harrison, Mr. Aragõa Drummond  40    Harrison
# 751  O'loughlin, Dr. William Francis Norman  63  O'loughlin
# 916                Simpson, Dr. John Edward  37     Simpson

# %%
# Signore title missing
newDF[newDF.Name.str.contains(u'Sig.')]
# Out:
#                                           Name Age    LastName
# 5              Allaria, Sig.. Battista Antonio  22     Allaria
# 35                            Banfi, Sig.. Ugo  24       Banfi
# 60                    Basilico, Sig.. Giovanni  27    Basilico
# 63                        Bazzi, Sig.. Narciso  33       Bazzi
# 79                    Bernardi, Sig.. Battista  22    Bernardi
# 172                       Casali, Sig.. Giulio  32      Casali
# 240                Crovella, Sig.. Paolo Luigi  17    Crovella
# 258                  De MARSICO,. Sig. Govanni  20          De
# 277              Donati, Sig.. Italo Francesco  17      Donati
# 316                           Fei, Sig.. Carlo  30         Fei
# 324        Fioravante, Sig.. Giuseppe Bertoldo  23  Fioravante
# 351        Gatti, Sig.. Gaspare Antonio Pietro  37       Gatti
# 357              Gilardino, Sig.. Vincenzo Pio  31   Gilardino
# 620                      Mattmann, Sig.. Adolf  20    Mattmann
# 707                 Monteverdi, Sig.. Giovanni  23  Monteverdi
# 732   Nannini, Sig.. Francesco Luigi Arcangelo  42     Nannini
# 763     Pachera, Sig.. Jean Baptiste Stanislas  19     Pachera
# 777                  Pedrini, Sig.. Alessandro  21     Pedrini
# 782                   Peracchio, Sig.. Alberto  20   Peracchio
# 783                Peracchio, Sig.. Sebastiano  17   Peracchio
# 786                     Perotti, Sig.. Alfonso  20     Perotti
# 800                        Piatti, Sig.. Louis  17      Piatti
# 801                Piazza, Sig.. Pompeo Gaspro  33      Piazza
# 808                        Poggi, Sig.. Emilio  28       Poggi
# 834                        Ratti, Sig.. Enrico  21       Ratti
# 843            Ricaldone, Sig.. Rinaldo Renato  22   Ricaldone
# 867                  Rotta, Sig.. Angelo Mario  23       Rotta
# 878   Saccaggi, Sig.. Giovanni Giuseppe Emilio  24    Saccaggi
# 879                  Salussolia, Sig.. Govanni  25  Salussolia
# 882                       Sartori, Sig.. Lazar  24     Sartori
# 890                     Scavino, Sig.. Candido  42     Scavino
# 899                       Sesia, Sig.. Giacomo  24       Sesia
# 988                      Testoni, Sig.. Ercole  23     Testoni
# 1003                   Tietz, Sig.. Carlo/Karl  27       Tietz
# 1015                     Urbini, Sig.. Roberto  20      Urbini
# 1017            Valvassori, Sig.. Ettore Luigi  35  Valvassori
# 1023         Vicat, Sig.. Alphonse Jean Eugene  21       Vicat
# 1027                      Vioni, Sig.. Roberto  25       Vioni
# 1028            Vögelin-dubach, Sig.. Johannes  35           V
# 1101                      Zanetti, Sig.. Minio  20     Zanetti
# 1102                       Zarracchi, Sig.. L.  26   Zarracchi

# %%
import string
def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if string.find(big_string, substring) != -1:
            return substring
    print big_string
    return np.nan

title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer','Sig.']

newDF['Title']=newDF['Name'].map(lambda x: substrings_in_string(x, title_list))
 
#replacing all titles with mr, mrs, miss, master
def replace_titles(x):
    title=x['Title']
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col','Sig.']:
        return 'Mr'
    elif title in ['Countess', 'Mme']:
        return 'Mrs'
    elif title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title =='Dr':
        return 'Mr'
    else:
        return title
    
newDF['Title']=newDF.apply(replace_titles, axis=1)
# Out:
# Monrós, Sr.. Joan Javier

# %%
newDF.head()
# Out:
#                           Name Age LastName Title
# 0   Abrams, Mr. William Thomas  34   Abrams    Mr
# 1       Adams, Mr. Robert John  26    Adams    Mr
# 2     Ahier, Mr. Percy Snowden  20    Ahier    Mr
# 3   Akerman, Mr. Albert Edward  31  Akerman    Mr
# 4  Akerman, Mr. Joseph Francis  37  Akerman    Mr

# %%
# Signore title missing
newDF[newDF.Name.str.contains(u'Sig.')]
# Out:
#                                           Name Age    LastName Title
# 5              Allaria, Sig.. Battista Antonio  22     Allaria    Mr
# 35                            Banfi, Sig.. Ugo  24       Banfi    Mr
# 60                    Basilico, Sig.. Giovanni  27    Basilico    Mr
# 63                        Bazzi, Sig.. Narciso  33       Bazzi    Mr
# 79                    Bernardi, Sig.. Battista  22    Bernardi    Mr
# 172                       Casali, Sig.. Giulio  32      Casali    Mr
# 240                Crovella, Sig.. Paolo Luigi  17    Crovella    Mr
# 258                  De MARSICO,. Sig. Govanni  20          De    Mr
# 277              Donati, Sig.. Italo Francesco  17      Donati    Mr
# 316                           Fei, Sig.. Carlo  30         Fei    Mr
# 324        Fioravante, Sig.. Giuseppe Bertoldo  23  Fioravante    Mr
# 351        Gatti, Sig.. Gaspare Antonio Pietro  37       Gatti    Mr
# 357              Gilardino, Sig.. Vincenzo Pio  31   Gilardino    Mr
# 620                      Mattmann, Sig.. Adolf  20    Mattmann    Mr
# 707                 Monteverdi, Sig.. Giovanni  23  Monteverdi    Mr
# 732   Nannini, Sig.. Francesco Luigi Arcangelo  42     Nannini    Mr
# 763     Pachera, Sig.. Jean Baptiste Stanislas  19     Pachera    Mr
# 777                  Pedrini, Sig.. Alessandro  21     Pedrini    Mr
# 782                   Peracchio, Sig.. Alberto  20   Peracchio    Mr
# 783                Peracchio, Sig.. Sebastiano  17   Peracchio    Mr
# 786                     Perotti, Sig.. Alfonso  20     Perotti    Mr
# 800                        Piatti, Sig.. Louis  17      Piatti    Mr
# 801                Piazza, Sig.. Pompeo Gaspro  33      Piazza    Mr
# 808                        Poggi, Sig.. Emilio  28       Poggi    Mr
# 834                        Ratti, Sig.. Enrico  21       Ratti    Mr
# 843            Ricaldone, Sig.. Rinaldo Renato  22   Ricaldone    Mr
# 867                  Rotta, Sig.. Angelo Mario  23       Rotta    Mr
# 878   Saccaggi, Sig.. Giovanni Giuseppe Emilio  24    Saccaggi    Mr
# 879                  Salussolia, Sig.. Govanni  25  Salussolia    Mr
# 882                       Sartori, Sig.. Lazar  24     Sartori    Mr
# 890                     Scavino, Sig.. Candido  42     Scavino    Mr
# 899                       Sesia, Sig.. Giacomo  24       Sesia    Mr
# 988                      Testoni, Sig.. Ercole  23     Testoni    Mr
# 1003                   Tietz, Sig.. Carlo/Karl  27       Tietz    Mr
# 1015                     Urbini, Sig.. Roberto  20      Urbini    Mr
# 1017            Valvassori, Sig.. Ettore Luigi  35  Valvassori    Mr
# 1023         Vicat, Sig.. Alphonse Jean Eugene  21       Vicat    Mr
# 1027                      Vioni, Sig.. Roberto  25       Vioni    Mr
# 1028            Vögelin-dubach, Sig.. Johannes  35           V    Mr
# 1101                      Zanetti, Sig.. Minio  20     Zanetti    Mr
# 1102                       Zarracchi, Sig.. L.  26   Zarracchi    Mr

# %%
# Get the Data
path = './Data/'
filename = 'titanic-data.csv'

titanic = pd.read_csv(path+filename)
print titanic.columns
print titanic.head()
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer']

# create a dictionary for replacement
newtitle = []
dicoTitle = {}
for word in title_list:
    txt = ', '+word+' '
    dicoTitle[txt] = ', '+word+'.'+' '
    
print dicoTitle
# Out:
# {', Capt ': ', Capt. ', ', Dr ': ', Dr. ', ', Countess ': ', Countess. ', ', Mrs ': ', Mrs. ', ', Rev ': ', Rev. ', ', Jonkheer ': ', Jonkheer. ', ', Mme ': ', Mme. ', ', Major ': ', Major. ', ', Master ': ', Master. ', ', Ms ': ', Ms. ', ', Mr ': ', Mr. ', ', Col ': ', Col. ', ', Miss ': ', Miss. ', ', Don ': ', Don. ', ', Mlle ': ', Mlle. '}

# %%
# loop in dictionary
for key in dicoTitle:
    print key
    #print dicoTitle[key]
# Out:
# , Capt
# , Dr
# , Countess
# , Mrs
# , Rev
# , Jonkheer
# , Mme
# , Major
# , Master
# , Ms
# , Mr
# , Col
# , Miss
# , Don
# , Mlle

# %%
def combine_dfs(df1, df2):
    '''
    Fill in this function to take 2 DataFrames, one with subway data and one with weather data,
    and return a single dataframe with one row for each date, hour, and location. Only include
    times and locations that have both subway data and weather data available.
    '''
    s1 = pd.merge(df1, df2, how='inner', on=['Name'])
    return s1

# %%
s2 = combine_dfs(newDF,titanic)
print s2
# Out:
#                Name Age_x LastName Title  PassengerId  Survived  Pclass   Sex  \
# 0  Kelly, Mr. James    44    Kelly    Mr          697         0       3  male
#
#    Age_y  SibSp  Parch  Ticket  Fare Cabin Embarked
# 0   44.0      0      0  363592  8.05   NaN        S

# %%
# All doctors are male
newDF[newDF.Name.str.contains(u'Kelly')]
# Out:
#                    Name Age LastName Title
# 528    Kelly, Mr. James  44    Kelly    Mr
# 529  Kelly, Mr. William  23    Kelly    Mr

# %%
# All doctors are male
titanic[titanic.Name.str.contains(u'Kelly')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 300          301         1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 573          574         1       3                         Kelly, Miss. Mary
# 696          697         0       3                          Kelly, Mr. James
# 706          707         1       2             Kelly, Mrs. Florence "Fannie"
#
#         Sex   Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 300  female   NaN      0      0    9234   7.75   NaN        Q
# 573  female   NaN      0      0   14312   7.75   NaN        Q
# 696    male  44.0      0      0  363592   8.05   NaN        S
# 706  female  45.0      0      0  223596  13.50   NaN        S

# %%
path = 'C:/Users/Diallo/Downloads/'
filename2 = 'testTitanic.csv'
test = pd.read_csv(path+filename2)
# All doctors are male
s2 = combine_dfs(test,newDF)
print s2
# Out:
#    PassengerId  Pclass              Name   Sex  Age_x  SibSp  Parch  Ticket  \
# 0          892       3  Kelly, Mr. James  male   34.5      0      0  330911
# 1         1008       3  Thomas, Mr. John  male    NaN      0      0    2681
#
#      Fare Cabin Embarked Age_y LastName Title
# 0  7.8292   NaN        Q    44    Kelly    Mr
# 1  6.4375   NaN        C    25   Thomas    Mr

# %%
for ix in titanic.index:
    #print ix
    string = titanic.loc[ix,'Name']
    m = re.search('^[a-zA-Z\']+', string)
    txt = m.group(0)
    t = txt.capitalize()
    titanic.loc[ix,'LastName'] = t

# %%
for ix in test.index:
    #print ix
    string = test.loc[ix,'Name']
    m = re.search('^[a-zA-Z\']+', string)
    txt = m.group(0)
    t = txt.capitalize()
    test.loc[ix,'LastName'] = t

# %%
def combine_dfs2(df1, df2):
    '''
    Fill in this function to take 2 DataFrames, one with subway data and one with weather data,
    and return a single dataframe with one row for each date, hour, and location. Only include
    times and locations that have both subway data and weather data available.
    '''
    s1 = pd.merge(df1, df2, how='inner', on=['LastName'])
    return s1

# %%
s2 = combine_dfs2(newDF,titanic)
print s2[s2.Fare <1]
# Out:
#                             Name_x Age_x    LastName Title  PassengerId  \
# 12     Andrews, Mr. Charles Edward    19     Andrews    Mr          807
# 14          Andrews, Mr. Archibald    38     Andrews    Mr          807
# 51     Campbell, Mr. Donald Samuel    28    Campbell    Mr          467
# 62         Cunningham, Mr. Bernard    35  Cunningham    Mr          414
# 63      Cunningham, Mr. Andrew Orr    38  Cunningham    Mr          414
# 134        Harrison, Mr. Norman E.    38    Harrison    Mr          264
# 135  Harrison, Mr. Aragõa Drummond    40    Harrison    Mr          264
# 161             Knight, Mr. George    49      Knight    Mr          733
# 162     Knight, Mr. Leonard George    21      Knight    Mr          733
# 164           Leonard, Mr. Matthew    25     Leonard    Mr          180
# 313             Watson, Mr. Willim    27      Watson    Mr          675
# 314     Watson, Mr. William Albert    15      Watson    Mr          675
#
#      Survived  Pclass                          Name_y   Sex  Age_y  SibSp  \
# 12          0       1          Andrews, Mr. Thomas Jr  male   39.0      0
# 14          0       1          Andrews, Mr. Thomas Jr  male   39.0      0
# 51          0       2           Campbell, Mr. William  male    NaN      0
# 62          0       2  Cunningham, Mr. Alfred Fleming  male    NaN      0
# 63          0       2  Cunningham, Mr. Alfred Fleming  male    NaN      0
# 134         0       1           Harrison, Mr. William  male   40.0      0
# 135         0       1           Harrison, Mr. William  male   40.0      0
# 161         0       2            Knight, Mr. Robert J  male    NaN      0
# 162         0       2            Knight, Mr. Robert J  male    NaN      0
# 164         0       3             Leonard, Mr. Lionel  male   36.0      0
# 313         0       2      Watson, Mr. Ennis Hastings  male    NaN      0
# 314         0       2      Watson, Mr. Ennis Hastings  male    NaN      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 12       0  112050   0.0   A36        S
# 14       0  112050   0.0   A36        S
# 51       0  239853   0.0   NaN        S
# 62       0  239853   0.0   NaN        S
# 63       0  239853   0.0   NaN        S
# 134      0  112059   0.0   B94        S
# 135      0  112059   0.0   B94        S
# 161      0  239855   0.0   NaN        S
# 162      0  239855   0.0   NaN        S
# 164      0    LINE   0.0   NaN        S
# 313      0  239856   0.0   NaN        S
# 314      0  239856   0.0   NaN        S

# %%
titanic[titanic.Name.str.contains(u'Leonard')]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 121          122         0       3
# 179          180         0       3
# 248          249         1       1
# 386          387         0       3
# 626          627         0       2
# 655          656         0       2
# 758          759         0       3
# 871          872         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 121                        Moore, Mr. Leonard Charles    male   NaN      0
# 179                               Leonard, Mr. Lionel    male  36.0      0
# 248                     Beckwith, Mr. Richard Leonard    male  37.0      1
# 386                   Goodwin, Master. Sidney Leonard    male   1.0      5
# 626                    Kirkland, Rev. Charles Leonard    male  57.0      0
# 655                         Hickman, Mr. Leonard Mark    male  24.0      2
# 758                      Theobald, Mr. Thomas Leonard    male  34.0      0
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
#
#      Parch        Ticket     Fare Cabin Embarked  LastName
# 7        1        349909  21.0750   NaN        S   Palsson
# 121      0     A4. 54510   8.0500   NaN        S     Moore
# 179      0          LINE   0.0000   NaN        S   Leonard
# 248      1         11751  52.5542   D35        S  Beckwith
# 386      2       CA 2144  46.9000   NaN        S   Goodwin
# 626      0        219533  12.3500   NaN        Q  Kirkland
# 655      0  S.O.C. 14879  73.5000   NaN        S   Hickman
# 758      0        363294   8.0500   NaN        S  Theobald
# 871      1         11751  52.5542   D35        S  Beckwith

# %%
newDF[newDF.Name.str.contains(u'Leonard')]
# Out:
#                                  Name Age    LastName Title
# 449          Hoare, Mr. Leonard James  19       Hoare    Mr
# 452           Hodgkinson, Mr. Leonard  46  Hodgkinson    Mr
# 554        Knight, Mr. Leonard George  21      Knight    Mr
# 569              Leonard, Mr. Matthew  25     Leonard    Mr
# 984               Taylor, Mr. Leonard  19      Taylor    Mr
# 1062  White, Mr. Leonard Lisle Oliver  32       White    Mr
# 1065         White, Mr. Frank Leonard  28       White    Mr

# %%
s2 = combine_dfs2(newDF,test)
print s2[s2.Fare <1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-442-27bc4a77efae> in <module>()
# ----> 1 s2 = combine_dfs2(newDF,test)
#       2 print s2[s2.Fare <1]
#
# <ipython-input-438-0e9295c26153> in combine_dfs2(df1, df2)
#       5     times and locations that have both subway data and weather data available.
#       6     '''
# ----> 7     s1 = pd.merge(df1, df2, how='inner', on=['LastName'])
#       8     return s1
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      56                          right_on=right_on, left_index=left_index,
#      57                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 58                          copy=copy, indicator=indicator)
#      59     return op.get_result()
#      60 if __debug__:
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\tools\merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     494         (self.left_join_keys,
#     495          self.right_join_keys,
# --> 496          self.join_names) = self._get_merge_keys()
#     497
#     498     def get_result(self):
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\tools\merge.pyc in _get_merge_keys(self)
#     745                 else:
#     746                     if not is_rkey(rk):
# --> 747                         right_keys.append(right[rk]._values)
#     748                         if lk == rk:
#     749                             # avoid key upcast in corner case (length-0)
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Diallo\Anaconda2\envs\todelete\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4443)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'LastName'
